# %%
import pandas as pd 
import numpy as np
from sklearn.impute import SimpleImputer
from sklearn.model_selection import train_test_split
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import OneHotEncoder
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error
from xgboost import XGBRegressor
from sklearn.linear_model import LassoCV
from sklearn import metrics
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.pipeline import make_pipeline
from sklearn.model_selection import KFold
from sklearn.model_selection import GridSearchCV, cross_val_score
from scipy.stats import skew
from scipy.special import boxcox1p
from scipy.stats import boxcox_normmax

# %%
from sklearn.linear_model import ElasticNetCV, LassoCV, RidgeCV
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.svm import SVR
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import RobustScaler
from sklearn.model_selection import KFold, cross_val_score
from sklearn.metrics import mean_squared_error, mean_absolute_error

from mlxtend.regressor import StackingCVRegressor

# %%
import warnings 
warnings.filterwarnings("ignore")
pd.set_option('display.max_columns', None)
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %%
train = pd.read_csv("C:/Users/Nurlan/Desktop/Datascience/Predit_The price/train.csv", index_col = 'Id')
test = pd.read_csv("C:/Users/Nurlan/Desktop/Datascience/Predit_The price/test.csv", index_col = 'Id')

# %%
train.head()
# Out:
#     MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# Id
# 1           60       RL         65.0     8450   Pave   NaN      Reg
# 2           20       RL         80.0     9600   Pave   NaN      Reg
# 3           60       RL         68.0    11250   Pave   NaN      IR1
# 4           70       RL         60.0     9550   Pave   NaN      IR1
# 5           60       RL         84.0    14260   Pave   NaN      IR1
#
#    LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# Id
# 1          Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 2          Lvl    AllPub       FR2       Gtl      Veenker      Feedr
# 3          Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 4          Lvl    AllPub    Corner       Gtl      Crawfor       Norm
# 5          Lvl    AllPub       FR2       Gtl      NoRidge       Norm
#
#    Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# Id
# ...

# %%
test.head()
# Out:
#       MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# Id
# 1461          20       RH         80.0    11622   Pave   NaN      Reg
# 1462          20       RL         81.0    14267   Pave   NaN      IR1
# 1463          60       RL         74.0    13830   Pave   NaN      IR1
# 1464          60       RL         78.0     9978   Pave   NaN      IR1
# 1465         120       RL         43.0     5005   Pave   NaN      IR1
#
#      LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# Id
# 1461         Lvl    AllPub    Inside       Gtl        NAmes      Feedr
# 1462         Lvl    AllPub    Corner       Gtl        NAmes       Norm
# 1463         Lvl    AllPub    Inside       Gtl      Gilbert       Norm
# 1464         Lvl    AllPub    Inside       Gtl      Gilbert       Norm
# 1465         HLS    AllPub    Inside       Gtl      StoneBr       Norm
#
#      Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# Id
# ...

# %%
train.shape
# Out:
# (1460, 80)

# %%
test.shape
# Out:
# (1459, 79)

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1460 entries, 1 to 1460
# Data columns (total 80 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   MSSubClass     1460 non-null   int64
#  1   MSZoning       1460 non-null   object
#  2   LotFrontage    1201 non-null   float64
#  3   LotArea        1460 non-null   int64
#  4   Street         1460 non-null   object
#  5   Alley          91 non-null     object
#  6   LotShape       1460 non-null   object
#  7   LandContour    1460 non-null   object
#  8   Utilities      1460 non-null   object
#  9   LotConfig      1460 non-null   object
#  10  LandSlope      1460 non-null   object
#  11  Neighborhood   1460 non-null   object
#  12  Condition1     1460 non-null   object
#  13  Condition2     1460 non-null   object
#  14  BldgType       1460 non-null   object
#  15  HouseStyle     1460 non-null   object
#  16  OverallQual    1460 non-null   int64
# ...

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1459 entries, 1461 to 2919
# Data columns (total 79 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   MSSubClass     1459 non-null   int64
#  1   MSZoning       1455 non-null   object
#  2   LotFrontage    1232 non-null   float64
#  3   LotArea        1459 non-null   int64
#  4   Street         1459 non-null   object
#  5   Alley          107 non-null    object
#  6   LotShape       1459 non-null   object
#  7   LandContour    1459 non-null   object
#  8   Utilities      1457 non-null   object
#  9   LotConfig      1459 non-null   object
#  10  LandSlope      1459 non-null   object
#  11  Neighborhood   1459 non-null   object
#  12  Condition1     1459 non-null   object
#  13  Condition2     1459 non-null   object
#  14  BldgType       1459 non-null   object
#  15  HouseStyle     1459 non-null   object
#  16  OverallQual    1459 non-null   int64
# ...

# %% [markdown]
# ## Checking for missing values

# %%
sns.set(rc = {'figure.figsize': (10,6)})

# %%
missing = train.isnull().sum()
missing = missing[missing>0]
missing.sort_values(inplace = True)
missing.plot.bar()

# %% [markdown]
# ## Visualize the Data

# %%
numerical_features = train.select_dtypes(exclude = ['object']).drop(['SalePrice'], axis = 1).copy()
print(numerical_features.columns)
# Out:
# Index(['MSSubClass', 'LotFrontage', 'LotArea', 'OverallQual', 'OverallCond',
#        'YearBuilt', 'YearRemodAdd', 'MasVnrArea', 'BsmtFinSF1', 'BsmtFinSF2',
#        'BsmtUnfSF', 'TotalBsmtSF', '1stFlrSF', '2ndFlrSF', 'LowQualFinSF',
#        'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath', 'HalfBath',
#        'BedroomAbvGr', 'KitchenAbvGr', 'TotRmsAbvGrd', 'Fireplaces',
#        'GarageYrBlt', 'GarageCars', 'GarageArea', 'WoodDeckSF', 'OpenPorchSF',
#        'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea', 'MiscVal',
#        'MoSold', 'YrSold'],
#       dtype='object')

# %%
categorical_variables = train.select_dtypes(include = ['object']).copy()
print(categorical_variables.columns)
# Out:
# Index(['MSZoning', 'Street', 'Alley', 'LotShape', 'LandContour', 'Utilities',
#        'LotConfig', 'LandSlope', 'Neighborhood', 'Condition1', 'Condition2',
#        'BldgType', 'HouseStyle', 'RoofStyle', 'RoofMatl', 'Exterior1st',
#        'Exterior2nd', 'MasVnrType', 'ExterQual', 'ExterCond', 'Foundation',
#        'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2',
#        'Heating', 'HeatingQC', 'CentralAir', 'Electrical', 'KitchenQual',
#        'Functional', 'FireplaceQu', 'GarageType', 'GarageFinish', 'GarageQual',
#        'GarageCond', 'PavedDrive', 'PoolQC', 'Fence', 'MiscFeature',
#        'SaleType', 'SaleCondition'],
#       dtype='object')

# %% [markdown]
# ## Distribution of Data

# %%
fig = plt.figure(figsize=(13,18))
for i in range(len(numerical_features.columns)):
    fig.add_subplot(9,4, i+1)
    sns.distplot(numerical_features.iloc[:,i].dropna() , rug = True, hist = True,
                label = 'UW', kde_kws = {'bw':0.1}, color = 'green')
    plt.xlabel(numerical_features.columns[i])
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Univariate Analysis

# %%
fig = plt.figure(figsize = (12, 18))
for i in range(len(numerical_features.columns)):
    fig.add_subplot(9,4, i+1)
    sns.boxplot(y = numerical_features.iloc[:,i])

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Bivariate Analysis

# %%
fig = plt.figure(figsize=(15,20))
for i in range(len(numerical_features.columns)):
    fig.add_subplot(9,4,i+1)
    sns.scatterplot(numerical_features.iloc[:,i], train['SalePrice'])
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Data Processing
#
# 1. Outliers
# 2. Removing certain features
# 3. Filling Numerical missing values
# 4. Filling Catgoricaal missing values

# %% [markdown]
# ## The features with outliers --->
#
# MscVal, TotalBsmtSF, BsmtFinSF1, GrLivArea, 1stFlrSF, EnclosedPorch, MiscVal, LowQualFinSF, LotFrontage, MasVnrArea, LotArea
#
#
# ## Let's look closer to this Features

# %%
figure, ((ax1, ax2), (ax3, ax4), (ax5, ax6), (ax7, ax8), (ax9, ax10)) = plt.subplots(nrows = 5, ncols =2)

figure.set_size_inches(16,28)
_ = sns.regplot(train['LotFrontage'], train['SalePrice'], ax = ax1)
_ = sns.regplot(train['MiscVal'], train['SalePrice'], ax = ax2)
_ = sns.regplot(train['TotalBsmtSF'], train['SalePrice'], ax = ax3)
_ = sns.regplot(train['BsmtFinSF1'], train['SalePrice'], ax = ax4)
_ = sns.regplot(train['GrLivArea'], train['SalePrice'], ax = ax5)
_ = sns.regplot(train['1stFlrSF'], train['SalePrice'], ax = ax6)
_ = sns.regplot(train['EnclosedPorch'], train['SalePrice'], ax = ax7)
_ = sns.regplot(train['LowQualFinSF'], train['SalePrice'], ax = ax8)
_ = sns.regplot(train['MasVnrArea'], train['SalePrice'], ax = ax9)
_ = sns.regplot(train['LotArea'], train['SalePrice'], ax = ax10)

# %%
train.shape
# Out:
# (1460, 80)

# %% [markdown]
# Removing outliers

# %%
train = train.drop(train[train['LotFrontage']>200].index)
train = train.drop(train[train['MiscVal'] > 5000].index)
train = train.drop(train[train['TotalBsmtSF'] > 4000].index)
train = train.drop(train[train['BsmtFinSF1'] > 4000].index)
train = train.drop(train[(train['GrLivArea'] > 4000) & (train['SalePrice'] < 300000)].index)
train = train.drop(train[train['1stFlrSF']>4000].index)
train = train.drop(train[train['EnclosedPorch']>400].index)
train = train.drop(train[(train['LowQualFinSF'] > 600) & (train['SalePrice'] > 400000)].index)
train = train.drop(train[train['MasVnrArea']>1200].index)
train = train.drop(train[train['LotArea'] > 100000].index)

# %% [markdown]
# Removing certain Features
#
# Find the highly-correlated (correlations greater than 0.8)

# %%
num_corelations = train.select_dtypes(exclude = 'object').corr()
plt.figure(figsize = (20,20))
plt.title('High Correlation')
sns.heatmap(num_corelations > 0.8, annot = True, square = True)

# %% [markdown]
# So highly correlated features ---> YearBuilt vs GarageYrBlt
#
#                                    1stFlrSF vs TotalBsmtSF
#
#                                    GrLivArea vs TotRmsAbvGrd
#
#                                    GarageCars vs GarageArea

# %%
corr = num_corelations.corr()
print(corr['SalePrice'].sort_values(ascending = False))
# Out:
# SalePrice        1.000000
# OverallQual      0.955658
# GarageCars       0.903239
# GarageArea       0.896312
# TotalBsmtSF      0.823405
# 1stFlrSF         0.803052
# GrLivArea        0.797433
# FullBath         0.796163
# MasVnrArea       0.790610
# YearBuilt        0.782893
# YearRemodAdd     0.752869
# GarageYrBlt      0.750694
# Fireplaces       0.720437
# TotRmsAbvGrd     0.619936
# LotFrontage      0.601135
# OpenPorchSF      0.580379
# WoodDeckSF       0.567785
# LotArea          0.524928
# BsmtFinSF1       0.491231
# BsmtUnfSF        0.443565
# HalfBath         0.387234
# BsmtFullBath     0.269141
# 2ndFlrSF         0.248204
# BedroomAbvGr     0.181318
# ScreenPorch      0.016683
# PoolArea        -0.015350
# MoSold          -0.030873
# 3SsnPorch       -0.043302
# YrSold          -0.218336
# BsmtFinSF2      -0.223131
# BsmtHalfBath    -0.238611
# LowQualFinSF    -0.259739
# MSSubClass      -0.280344
# MiscVal         -0.348786
# KitchenAbvGr    -0.366944
# ...

# %%
train.drop(columns = ['GarageArea','TotRmsAbvGrd','GarageYrBlt','1stFlrSF'], axis = 1, inplace = True)
test.drop(columns = ['GarageArea','TotRmsAbvGrd','GarageYrBlt','1stFlrSF'], axis = 1, inplace = True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-26-104d57eaa505> in <module>
# ----> 1 train.drop(columns = ['GarageArea','TotRmsAbvGrd','GarageYrBlt','1stFlrSF'], axis = 1, inplace = True)
#       2 test.drop(columns = ['GarageArea','TotRmsAbvGrd','GarageYrBlt','1stFlrSF'], axis = 1, inplace = True)
#
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3995             level=level,
#    3996             inplace=inplace,
# -> 3997             errors=errors,
#    3998         )
#    3999
#
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3934         for axis, labels in axes.items():
# ...

# %%
train.shape
# Out:
# (1448, 76)

# %%
train.columns
# Out:
# Index(['MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street', 'Alley',
#        'LotShape', 'LandContour', 'Utilities', 'LotConfig', 'LandSlope',
#        'Neighborhood', 'Condition1', 'Condition2', 'BldgType', 'HouseStyle',
#        'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd', 'RoofStyle',
#        'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType', 'MasVnrArea',
#        'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual', 'BsmtCond',
#        'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1', 'BsmtFinType2',
#        'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating', 'HeatingQC',
#        'CentralAir', 'Electrical', '2ndFlrSF', 'LowQualFinSF', 'GrLivArea',
#        'BsmtFullBath', 'BsmtHalfBath', 'FullBath', 'HalfBath', 'BedroomAbvGr',
#        'KitchenAbvGr', 'KitchenQual', 'Functional', 'Fireplaces',
#        'FireplaceQu', 'GarageType', 'GarageFinish', 'GarageCars', 'GarageQual',
#        'GarageCond', 'PavedDrive', 'WoodDeckSF', 'OpenPorchSF',
# ...

# %%
#Useless features

train.drop(columns = ['Street' , 'Utilities'] , inplace = True)
test.drop(columns = ['Street' , 'Utilities'] , inplace = True)

# %%
#The most missing values

train.isnull().mean().sort_values(ascending = False).head(3)
# Out:
# PoolQC         0.996547
# MiscFeature    0.965470
# Alley          0.937845
# dtype: float64

# %%
train.drop(columns = ['PoolQC','MiscFeature','Alley'], axis = 1, inplace = True)
test.drop(columns = ['PoolQC','MiscFeature','Alley'], axis = 1, inplace = True)

# %%
test.isnull().mean().sort_values(ascending = False).head(3)
# Out:
# Fence          0.801234
# FireplaceQu    0.500343
# LotFrontage    0.155586
# dtype: float64

# %% [markdown]
# ## Filling numeric missing values

# %%
#Check Train and Test Data missing values percentage 

null = pd.DataFrame(data = {'Train Null Percentage' : train.isnull().sum()[train.isnull().sum()>0] ,
                           'Test Null Percentage' : test.isnull().sum()[test.isnull().sum()>0]})

# %%
null = (null/len(train)) * 100
null.index.name = 'Feature'
null
# Out:
#               Train Null Percentage  Test Null Percentage
# Feature
# BsmtCond                   2.555249              3.107735
# BsmtExposure               2.624309              3.038674
# BsmtFinSF1                      NaN              0.069061
# BsmtFinSF2                      NaN              0.069061
# BsmtFinType1               2.555249              2.900552
# BsmtFinType2               2.624309              2.900552
# BsmtFullBath                    NaN              0.138122
# BsmtHalfBath                    NaN              0.138122
# BsmtQual                   2.555249              3.038674
# BsmtUnfSF                       NaN              0.069061
# Electrical                 0.069061                   NaN
# Exterior1st                     NaN              0.069061
# Exterior2nd                     NaN              0.069061
# Fence                     80.662983             80.732044
# FireplaceQu               47.582873             50.414365
# ...

# %%
train.isnull().sum().sort_values(ascending = False)[:60]
# Out:
# Fence            1168
# FireplaceQu       689
# LotFrontage       254
# GarageQual         81
# GarageCond         81
# GarageFinish       81
# GarageType         81
# BsmtFinType2       38
# BsmtExposure       38
# BsmtQual           37
# BsmtCond           37
# BsmtFinType1       37
# MasVnrArea          8
# MasVnrType          8
# Electrical          1
# Exterior1st         0
# RoofMatl            0
# ExterQual           0
# Exterior2nd         0
# YearRemodAdd        0
# ExterCond           0
# Foundation          0
# RoofStyle           0
# SalePrice           0
# YearBuilt           0
# OverallCond         0
# OverallQual         0
# HouseStyle          0
# BldgType            0
# Condition2          0
# Condition1          0
# Neighborhood        0
# LandSlope           0
# LotConfig           0
# LandContour         0
# LotShape            0
# LotArea             0
# MSZoning            0
# BsmtFinSF1          0
# Heating             0
# BsmtFinSF2          0
# ...

# %%
train_num_features = train.select_dtypes(exclude = 'object').isnull().mean()
test_num_features = test.select_dtypes(exclude = 'object').isnull().mean()

num_null_features = pd.DataFrame(data = {'Missing Num Train Percentage: ': 
                                        train_num_features[train_num_features>0], 'Missing Num Test Percentage':
                                        test_num_features[test_num_features>0]})
num_null_features.index.name = 'Numerical Features'
num_null_features
# Out:
#                     Missing Num Train Percentage:   \
# Numerical Features
# BsmtFinSF1                                     NaN
# BsmtFinSF2                                     NaN
# BsmtFullBath                                   NaN
# BsmtHalfBath                                   NaN
# BsmtUnfSF                                      NaN
# GarageCars                                     NaN
# LotFrontage                               0.175414
# MasVnrArea                                0.005525
# TotalBsmtSF                                    NaN
#
#                     Missing Num Test Percentage
# Numerical Features
# BsmtFinSF1                             0.000685
# BsmtFinSF2                             0.000685
# BsmtFullBath                           0.001371
# BsmtHalfBath                           0.001371
# BsmtUnfSF                              0.000685
# GarageCars                             0.000685
# LotFrontage                            0.155586
# ...

# %%
for df in [train, test]:
    for col in ('GarageCars' , 'BsmtFinSF1' , 'BsmtFinSF2', 'BsmtFullBath' , 'BsmtUnfSF',
                'MasVnrArea' , 'TotalBsmtSF'):
        df[col] = df[col].fillna(0)

# %%
_ = sns.regplot(train['LotFrontage'] , train['SalePrice'])

# %% [markdown]
# We will deal with 'LotFrontage' later because it is in an important feature

# %% [markdown]
# ## Filling Categorical Missing Values

# %%
cat_col = train.select_dtypes(include = 'object').columns
print(cat_col)
# Out:
# Index(['MSZoning', 'LotShape', 'LandContour', 'LotConfig', 'LandSlope',
#        'Neighborhood', 'Condition1', 'Condition2', 'BldgType', 'HouseStyle',
#        'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType',
#        'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual', 'BsmtCond',
#        'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2', 'Heating', 'HeatingQC',
#        'CentralAir', 'Electrical', 'KitchenQual', 'Functional', 'FireplaceQu',
#        'GarageType', 'GarageFinish', 'GarageQual', 'GarageCond', 'PavedDrive',
#        'Fence', 'SaleType', 'SaleCondition'],
#       dtype='object')

# %%
train_cat = train.select_dtypes(include = 'object').isnull().mean()
test_cat = test.select_dtypes(include = 'object').isnull().mean()

cat_null_var = pd.DataFrame(data = {'Train Cat. Null variables': train_cat[train_cat>0],
                                    'Test Cat. Null variables' : test_cat[test_cat>0]})
cat_null_var.index.name = 'Categorical Features'
cat_null_var
# Out:
#                       Train Cat. Null variables  Test Cat. Null variables
# Categorical Features
# BsmtCond                               0.025552                  0.030843
# BsmtExposure                           0.026243                  0.030158
# BsmtFinType1                           0.025552                  0.028787
# BsmtFinType2                           0.026243                  0.028787
# BsmtQual                               0.025552                  0.030158
# Electrical                             0.000691                       NaN
# Exterior1st                                 NaN                  0.000685
# Exterior2nd                                 NaN                  0.000685
# Fence                                  0.806630                  0.801234
# FireplaceQu                            0.475829                  0.500343
# Functional                                  NaN                  0.001371
# ...

# %%
columns = len(cat_col)/ 4 + 1

fg, ax = plt.subplots(figsize = (20,30))
for i, col in enumerate(cat_col):
    fg.add_subplot(columns, 4, i+1)
    sns.countplot(train[col])
    plt.xlabel(col)
    plt.yticks(rotation = 90)
plt.tight_layout()
plt.show()

# %%
var = train['KitchenQual']
f, ax = plt.subplots(figsize = (16,6))
sns.boxplot(y = train.SalePrice, x = var)
plt.show()

# %%
f, ax = plt.subplots(figsize=(12,8))
sns.boxplot(y = train.SalePrice, x = train.Neighborhood)
plt.xticks(rotation = 45)
plt.show()

# %%
fig = plt.figure(figsize = (12.5,4))
sns.countplot(x = 'Neighborhood', data=train)
plt.xticks(rotation=90)
plt.ylabel('Frequency')
plt.show()

# %%
for df in [train, test]:
    for col in ('GarageType', 'GarageFinish', 'GarageQual', 'GarageCond', 'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1',
                  'BsmtFinType2', 'Neighborhood', 'BldgType', 'HouseStyle', 'MasVnrType', 'FireplaceQu', 'Fence', 'BsmtHalfBath'):
        df[col] = df[col].fillna('None')

# %%
for df in [train, test]:
    for col in ('LotShape', 'LandContour', 'LotConfig', 'LandSlope', 'Condition1', 'RoofStyle',
                  'Electrical', 'Functional', 'KitchenQual', 'Exterior1st', 'Exterior2nd', 'SaleType', 'ExterQual', 'ExterCond',
                  'Foundation', 'HeatingQC', 'CentralAir', 'Electrical', 'KitchenQual', 'PavedDrive', 'SaleType', 'SaleCondition'):
        df[col] = df[col].fillna(df[col].mode()[0])

# %%
train_cat_features = train.select_dtypes(include = ['object']).isnull().mean()
test_cat_features = test.select_dtypes(include = ['object']).isnull().mean()

cat_null_features = pd.DataFrame(data = {"Missing Cat Train Percent: ":train_cat_features[train_cat_features>0],
                                        "Missing Cat Test Percent:":test_cat_features[test_cat_features>0]})
cat_null_features.index.name = "Categorical Features"
cat_null_features
# Out:
#                       Missing Cat Train Percent:   Missing Cat Test Percent:
# Categorical Features
# MSZoning                                      NaN                   0.002742

# %% [markdown]
# Filling missing values in "LotFrontage"

# %%
_=sns.regplot(train['LotFrontage'], train['SalePrice'])

# %% [markdown]
# LotFrontage is correleated to Neighborhood, so we fill in the median based off Neighborhood feature

# %%
train['LotFrontage'] = train.groupby('Neighborhood')['LotFrontage'].apply(lambda x: x.fillna(x.median()))
test['LotFrontage'] = test.groupby('Neighborhood')['LotFrontage'].apply(lambda x: x.fillna(x.median()))

# %%
train.corr()['SalePrice'].sort_values(ascending=False)
# Out:
# SalePrice        1.000000
# OverallQual      0.797594
# GrLivArea        0.732913
# TotalBsmtSF      0.649764
# GarageCars       0.643297
# FullBath         0.558228
# YearBuilt        0.530708
# YearRemodAdd     0.513826
# MasVnrArea       0.472856
# Fireplaces       0.468108
# BsmtFinSF1       0.402233
# LotFrontage      0.371609
# LotArea          0.359973
# OpenPorchSF      0.326176
# WoodDeckSF       0.323673
# 2ndFlrSF         0.315146
# HalfBath         0.288594
# BsmtUnfSF        0.221782
# BsmtFullBath     0.221738
# BedroomAbvGr     0.163770
# ScreenPorch      0.114242
# PoolArea         0.101561
# 3SsnPorch        0.046330
# BsmtFinSF2      -0.018791
# BsmtHalfBath    -0.020676
# LowQualFinSF    -0.029406
# MiscVal         -0.041791
# OverallCond     -0.076380
# EnclosedPorch   -0.135568
# KitchenAbvGr    -0.137327
# Name: SalePrice, dtype: float64

# %%
train.isnull().sum().sort_values(ascending=False)
# Out:
# YrSold          1448
# SalePrice          0
# Foundation         0
# Exterior1st        0
# Exterior2nd        0
#                 ...
# LowQualFinSF       0
# 2ndFlrSF           0
# Electrical         0
# CentralAir         0
# MSSubClass         0
# Length: 71, dtype: int64

# %%
test.isnull().sum().sort_values(ascending=False)
# Out:
# SaleCondition    0
# Foundation       0
# Exterior1st      0
# Exterior2nd      0
# MasVnrType       0
#                 ..
# LowQualFinSF     0
# 2ndFlrSF         0
# Electrical       0
# CentralAir       0
# MSSubClass       0
# Length: 70, dtype: int64

# %% [markdown]
# Filling missing values in "MSZoning"

# %%
train['MSSubClass'] = train['MSSubClass'].apply(str)
test['MSSubClass'] = test['MSSubClass'].apply(str)

train['MoSold'] = train['MoSold'].apply(str)
test['MoSold'] = test['MoSold'].apply(str)

train['YrSold'] = test['MoSold'].apply(str)
test['YrSold'] = test['MoSold'].apply(str)

# %%
train['MSZoning'] = train.groupby('MSSubClass')['MSZoning'].transform(lambda x: x.fillna(x.mode()[0]))
test['MSZoning'] = test.groupby('MSSubClass')['MSZoning'].transform(lambda x: x.fillna(x.mode()[0]))

# %%
train.isnull().sum()
# Out:
# MSSubClass          0
# MSZoning            0
# LotFrontage         0
# LotArea             0
# LotShape            0
#                  ...
# MoSold              0
# YrSold           1448
# SaleType            0
# SaleCondition       0
# SalePrice           0
# Length: 71, dtype: int64

# %%
train.drop('YrSold', axis = 1, inplace = True)

# %%
test.drop('YrSold', axis = 1, inplace = True)

# %%
train.isnull().sum().sort_values(ascending = False)
# Out:
# SalePrice       0
# Foundation      0
# Exterior1st     0
# Exterior2nd     0
# MasVnrType      0
#                ..
# LowQualFinSF    0
# 2ndFlrSF        0
# Electrical      0
# CentralAir      0
# MSSubClass      0
# Length: 70, dtype: int64

# %%
test.isnull().sum().sort_values(ascending = False)
# Out:
# SaleCondition    0
# ExterCond        0
# RoofMatl         0
# Exterior1st      0
# Exterior2nd      0
#                 ..
# 2ndFlrSF         0
# Electrical       0
# CentralAir       0
# HeatingQC        0
# MSSubClass       0
# Length: 69, dtype: int64

# %% [markdown]
# ### Feature engineering

# %%
list(train.select_dtypes(exclude = ['object']).columns)
# Out:
# ['LotFrontage',
#  'LotArea',
#  'OverallQual',
#  'OverallCond',
#  'YearBuilt',
#  'YearRemodAdd',
#  'MasVnrArea',
#  'BsmtFinSF1',
#  'BsmtFinSF2',
#  'BsmtUnfSF',
#  'TotalBsmtSF',
#  '2ndFlrSF',
#  'LowQualFinSF',
#  'GrLivArea',
#  'BsmtFullBath',
#  'BsmtHalfBath',
#  'FullBath',
#  'HalfBath',
#  'BedroomAbvGr',
#  'KitchenAbvGr',
#  'Fireplaces',
#  'GarageCars',
#  'WoodDeckSF',
#  'OpenPorchSF',
#  'EnclosedPorch',
#  '3SsnPorch',
#  'ScreenPorch',
#  'PoolArea',
#  'MiscVal',
#  'SalePrice']

# %%
figure, (ax1, ax2, ax3) = plt.subplots(nrows=1, ncols=3)
figure.set_size_inches(20, 10)
_ = sns.regplot(train['TotalBsmtSF'], train['SalePrice'], ax=ax1)
_ = sns.regplot(train['2ndFlrSF'], train['SalePrice'], ax=ax2)
_ = sns.regplot(train['2ndFlrSF'] + train['TotalBsmtSF'], train['SalePrice'], ax=ax3)

# %%
train['TotalSF'] = train['2ndFlrSF'] + train['TotalBsmtSF']
test['TotalSF'] = test['2ndFlrSF'] + test['TotalBsmtSF']

# %% [markdown]
# Create Total Bath Feature

# %%
figure, ((ax1, ax2), (ax3, ax4)) = plt.subplots(nrows = 2, ncols = 2)
figure.set_size_inches(14, 10)
_ = sns.barplot(train['BsmtFullBath'], train['SalePrice'], ax=ax1)
_ = sns.barplot(train['FullBath'], train['SalePrice'], ax=ax2)
_ = sns.barplot(train['BsmtHalfBath'], train['SalePrice'], ax=ax3)
_ = sns.barplot(train['BsmtFullBath'] + train['FullBath'] + train['BsmtHalfBath'] + train['HalfBath'], train['SalePrice'], ax=ax4)

# %%
train['TotalBath'] = train['BsmtFullBath'] + train['FullBath'] + (0.5 * train['BsmtHalfBath']) + (0.5*train['HalfBath'])
test['TotalBath'] = test['BsmtFullBath'] + test['FullBath'] + test['BsmtHalfBath'] + test['HalfBath']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\pandas\core\ops\array_ops.py in na_arithmetic_op(left, right, op, str_rep)
#     148     try:
# --> 149         result = expressions.evaluate(op, str_rep, left, right)
#     150     except TypeError:
#
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\pandas\core\computation\expressions.py in evaluate(op, op_str, a, b, use_numexpr)
#     207     if use_numexpr:
# --> 208         return _evaluate(op, op_str, a, b)
#     209     return _evaluate_standard(op, op_str, a, b)
#
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\pandas\core\computation\expressions.py in _evaluate_standard(op, op_str, a, b)
#      69     with np.errstate(all="ignore"):
# ...

# %%
train.head()
# Out:
#    MSSubClass MSZoning  LotFrontage  LotArea LotShape LandContour LotConfig  \
# Id
# 1          60       RL         65.0     8450      Reg         Lvl    Inside
# 2          20       RL         80.0     9600      Reg         Lvl       FR2
# 3          60       RL         68.0    11250      IR1         Lvl    Inside
# 4          70       RL         60.0     9550      IR1         Lvl    Corner
# 5          60       RL         84.0    14260      IR1         Lvl       FR2
#
#    LandSlope Neighborhood Condition1 Condition2 BldgType HouseStyle  \
# Id
# 1        Gtl      CollgCr       Norm       Norm     1Fam     2Story
# 2        Gtl      Veenker      Feedr       Norm     1Fam     1Story
# 3        Gtl      CollgCr       Norm       Norm     1Fam     2Story
# 4        Gtl      Crawfor       Norm       Norm     1Fam     2Story
# 5        Gtl      NoRidge       Norm       Norm     1Fam     2Story
#
#     OverallQual  OverallCond  YearBuilt  YearRemodAdd RoofStyle RoofMatl  \
# Id
# ...

# %% [markdown]
# Create 'YrBuiltAndRemod' feture

# %%
figure, (ax1, ax2, ax3) = plt.subplots(nrows=1, ncols=3)
figure.set_size_inches(18, 8)
_ = sns.regplot(train['YearBuilt'], train['SalePrice'], ax=ax1)
_ = sns.regplot(train['YearRemodAdd'], train['SalePrice'], ax=ax2)
_ = sns.regplot(train['YearBuilt'] + train['YearRemodAdd'], train['SalePrice'], ax=ax3)

# %%
train['YrBltAndRemod'] = train['YearBuilt'] + (train['YearRemodAdd']/2)
test['YrBltAndRemod'] = test['YearBuilt'] + (test['YearRemodAdd']/2)

# %%
train.head()
# Out:
#    MSSubClass MSZoning  LotFrontage  LotArea LotShape LandContour LotConfig  \
# Id
# 1          60       RL         65.0     8450      Reg         Lvl    Inside
# 2          20       RL         80.0     9600      Reg         Lvl       FR2
# 3          60       RL         68.0    11250      IR1         Lvl    Inside
# 4          70       RL         60.0     9550      IR1         Lvl    Corner
# 5          60       RL         84.0    14260      IR1         Lvl       FR2
#
#    LandSlope Neighborhood Condition1 Condition2 BldgType HouseStyle  \
# Id
# 1        Gtl      CollgCr       Norm       Norm     1Fam     2Story
# 2        Gtl      Veenker      Feedr       Norm     1Fam     1Story
# 3        Gtl      CollgCr       Norm       Norm     1Fam     2Story
# 4        Gtl      Crawfor       Norm       Norm     1Fam     2Story
# 5        Gtl      NoRidge       Norm       Norm     1Fam     2Story
#
#     OverallQual  OverallCond  YearBuilt  YearRemodAdd RoofStyle RoofMatl  \
# Id
# ...

# %% [markdown]
# Create 'PorchSF' feature

# %%
figure, ((ax1, ax2, ax3), (ax4, ax5, ax6)) = plt.subplots(nrows=2, ncols=3)
figure.set_size_inches(20, 10)
_ = sns.regplot(train['OpenPorchSF'], train['SalePrice'], ax=ax1)
_ = sns.regplot(train['3SsnPorch'], train['SalePrice'], ax=ax2)
_ = sns.regplot(train['EnclosedPorch'], train['SalePrice'], ax=ax3)
_ = sns.regplot(train['ScreenPorch'], train['SalePrice'], ax=ax4)
_ = sns.regplot(train['WoodDeckSF'], train['SalePrice'], ax=ax5)
_ = sns.regplot((train['OpenPorchSF']+train['3SsnPorch']+train['EnclosedPorch']+train['ScreenPorch']+train['WoodDeckSF']), train['SalePrice'], ax=ax6)

# %%
train['Porch_SF'] = (train['OpenPorchSF'] + train['3SsnPorch'] + train['EnclosedPorch'] + train['ScreenPorch'] + train['WoodDeckSF'])
test['Porch_SF'] = (test['OpenPorchSF'] + test['3SsnPorch'] + test['EnclosedPorch'] + test['ScreenPorch'] + test['WoodDeckSF'])

# %%
train.head()
# Out:
#    MSSubClass MSZoning  LotFrontage  LotArea LotShape LandContour LotConfig  \
# Id
# 1          60       RL         65.0     8450      Reg         Lvl    Inside
# 2          20       RL         80.0     9600      Reg         Lvl       FR2
# 3          60       RL         68.0    11250      IR1         Lvl    Inside
# 4          70       RL         60.0     9550      IR1         Lvl    Corner
# 5          60       RL         84.0    14260      IR1         Lvl       FR2
#
#    LandSlope Neighborhood Condition1 Condition2 BldgType HouseStyle  \
# Id
# 1        Gtl      CollgCr       Norm       Norm     1Fam     2Story
# 2        Gtl      Veenker      Feedr       Norm     1Fam     1Story
# 3        Gtl      CollgCr       Norm       Norm     1Fam     2Story
# 4        Gtl      Crawfor       Norm       Norm     1Fam     2Story
# 5        Gtl      NoRidge       Norm       Norm     1Fam     2Story
#
#     OverallQual  OverallCond  YearBuilt  YearRemodAdd RoofStyle RoofMatl  \
# Id
# ...

# %% [markdown]
# ## Creating extra features and changing types

# %%
train['Has2ndfloor'] = train['2ndFlrSF'].apply(lambda x: 1 if x>0 else 0)
train['HasBsmt'] = train['TotalBsmtSF'].apply(lambda x: 1 if x>0 else 0)
train['HasFirePlace'] = train['Fireplaces'].apply(lambda x: 1 if x>0 else 0)
train['Has2ndFlr']=train['2ndFlrSF'].apply(lambda x: 1 if x > 0 else 0)
train['HasBsmt']=train['TotalBsmtSF'].apply(lambda x: 1 if x > 0 else 0)

test['Has2ndfloor'] = test['2ndFlrSF'].apply(lambda x: 1 if x > 0 else 0)
test['HasBsmt'] = test['TotalBsmtSF'].apply(lambda x: 1 if x > 0 else 0)
test['HasFirePlace'] = test['Fireplaces'].apply(lambda x: 1 if x > 0 else 0)
test['Has2ndFlr']=test['2ndFlrSF'].apply(lambda x: 1 if x > 0 else 0)
test['HasBsmt']=test['TotalBsmtSF'].apply(lambda x: 1 if x > 0 else 0)

# %%
train['LotArea'] = train['LotArea'].astype(np.int64)
test['LotArea'] = test['LotArea'].astype(np.int64)
train['MasVnrArea'] = train['MasVnrArea'].astype(np.int64)
test['MasVnrArea'] = test['MasVnrArea'].astype(np.int64)

# %% [markdown]
# ## SalePrice Distribution Visualization

# %%
fig = plt.figure(figsize=(11, 11))
print("Skew of SalePrice", train.SalePrice.skew())
plt.hist(train.SalePrice, normed=1, color='red')
plt.show()
# Out:
# Skew of SalePrice 1.849175700649413

# %% [markdown]
# ### So the graph shows that SalePrice is skewed to the right and must be modified

# %%
fig = plt.figure(figsize=(11, 11))

print("Skew of Log-transformed SalePrice: ", np.log1p(train.SalePrice).skew())
plt.hist(np.log1p(train.SalePrice), color="green")
plt.show()
# Out:
# Skew of Log-transformed SalePrice:  0.11148352116819059

# %% [markdown]
# ## Modeling

# %%
X = train.drop(['SalePrice'], axis=1)
y = np.log1p(train['SalePrice'])

# %%
X_train, X_valid, y_train, y_valid = train_test_split(X, y, test_size=.2, train_size=.8, random_state=0)

# %%
test.head()
# Out:
#      MSSubClass MSZoning  LotFrontage  LotArea LotShape LandContour LotConfig  \
# Id
# 1461         20       RH         80.0    11622      Reg         Lvl    Inside
# 1462         20       RL         81.0    14267      IR1         Lvl    Corner
# 1463         60       RL         74.0    13830      IR1         Lvl    Inside
# 1464         60       RL         78.0     9978      IR1         Lvl    Inside
# 1465        120       RL         43.0     5005      IR1         HLS    Inside
#
#      LandSlope Neighborhood Condition1 Condition2 BldgType HouseStyle  \
# Id
# 1461       Gtl        NAmes      Feedr       Norm     1Fam     1Story
# 1462       Gtl        NAmes       Norm       Norm     1Fam     1Story
# 1463       Gtl      Gilbert       Norm       Norm     1Fam     2Story
# 1464       Gtl      Gilbert       Norm       Norm     1Fam     2Story
# 1465       Gtl      StoneBr       Norm       Norm   TwnhsE     1Story
#
# ...

# %%
train.head()
# Out:
#    MSSubClass MSZoning  LotFrontage  LotArea LotShape LandContour LotConfig  \
# Id
# 1          60       RL         65.0     8450      Reg         Lvl    Inside
# 2          20       RL         80.0     9600      Reg         Lvl       FR2
# 3          60       RL         68.0    11250      IR1         Lvl    Inside
# 4          70       RL         60.0     9550      IR1         Lvl    Corner
# 5          60       RL         84.0    14260      IR1         Lvl       FR2
#
#    LandSlope Neighborhood Condition1 Condition2 BldgType HouseStyle  \
# Id
# 1        Gtl      CollgCr       Norm       Norm     1Fam     2Story
# 2        Gtl      Veenker      Feedr       Norm     1Fam     1Story
# 3        Gtl      CollgCr       Norm       Norm     1Fam     2Story
# 4        Gtl      Crawfor       Norm       Norm     1Fam     2Story
# 5        Gtl      NoRidge       Norm       Norm     1Fam     2Story
#
#     OverallQual  OverallCond  YearBuilt  YearRemodAdd RoofStyle RoofMatl  \
# Id
# ...
